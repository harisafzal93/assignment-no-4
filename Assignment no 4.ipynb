# %%
# Guest List

guests = [
    "Hammad",
    "Hamza",
    "Fahad"]


# Messages

messages = {
    "Hammad":
    """Dear Mr. Hammad,

    I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in electrical engineering and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.
    
Looking forward to your positive response.

Best regards,
Haris Afzal
""",
    "Hamza":
    """Dear Mr. Hamza,

    I hope this message finds you well. It would be an absolute delight and privilege to have you join me for dinner. Your groundbreaking research in radioactivity and your dedication to science have deeply influenced my life. I would love to hear more about your journey and wisdom.

With great admiration,
Haris Afzal
""",
    "Fahad":"""
    Dear Mr. Fahad,

    I am reaching out with the sincere hope that you will accept my invitation to dinner. Your unparalleled genius in literature and drama has always fascinated me. It would be a remarkable experience to converse with you and gain insight into your incredible mind.

Yours sincerely,
Haris Afzal"""}


# Printing the messages

for guest in guests:
    print(messages[guest])
# Out:
# Dear Mr. Hammad,
#
#     I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in electrical engineering and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.
#
# Looking forward to your positive response.
#
# Best regards,
# Haris Afzal
#
# Dear Mr. Hamza,
#
#     I hope this message finds you well. It would be an absolute delight and privilege to have you join me for dinner. Your groundbreaking research in radioactivity and your dedication to science have deeply influenced my life. I would love to hear more about your journey and wisdom.
#
# With great admiration,
# Haris Afzal
#
#
#     Dear Mr. Fahad,
#
# ...

# %%
# Initial guest list
guests = [
    "Hammad",
    "Hamza",
    "Fahad"]

# Messages
messages = {
    "Hammad":
    """Dear Mr. Hammad,

    I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in electrical engineering and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.
    
Looking forward to your positive response.

Best regards,
Haris Afzal
""",
    "Hamza": "\n"
    
    """Dear Mr. Hamza,

    I hope this message finds you well. It would be an absolute delight and privilege to have you join me for dinner. Your groundbreaking research in radioactivity and your dedication to science have deeply influenced my life. I would love to hear more about your journey and wisdom.

With great admiration,
Haris Afzal
""",
  "Fahad":
"""Dear Mr. Fahad,

    I am reaching out with the sincere hope that you will accept my invitation to dinner. Your unparalleled genius in literature and drama has always fascinated me. It would be a remarkable experience to converse with you and gain insight into your incredible mind.

Yours sincerely,
Haris Afzal"""}

# Printing the initial messages
print ("Initial Invitations:")
for guest in guests:
    print (messages[guest])

# Guest who can't make it
guest_cant_make_it = "Hammad"
print(f"\nUnfortunately, {guest_cant_make_it} can't make it to the dinner.\n")

# Replace the guest who can't make it with a new guest
new_guest = "Basit"
guests[guests.index(guest_cant_make_it)] = new_guest

# Add new message for the new guest
messages[new_guest] = """
Dear Mr. Basit,

I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in computer science and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.

Looking forward to your positive response.

Best regards,
Haris Afzal"""

# Printing the updated messages
print("Updated Invitation:")
for guest in guests:
    print (messages[guest])
# Out:
# Initial Invitations:
# Dear Mr. Hammad,
#
#     I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in electrical engineering and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.
#
# Looking forward to your positive response.
#
# Best regards,
# Haris Afzal
#
#
# Dear Mr. Hamza,
#
#     I hope this message finds you well. It would be an absolute delight and privilege to have you join me for dinner. Your groundbreaking research in radioactivity and your dedication to science have deeply influenced my life. I would love to hear more about your journey and wisdom.
#
# With great admiration,
# Haris Afzal
#
# Dear Mr. Fahad,
#
# ...

# %%
# Initial guest list after replacement 
guests = ["Basit",
          "Hamza",
          "Fahad"]

# Messages
messages = {
    "Basit":
"""Dear Mr. Basit,

I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in electrical engineering and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.

Looking forward to your positive response.

Best regards,
Haris Afzal""",
    
    "Hamza":
    "\n"
"""Dear Mr. Hamza,

I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in computer science and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.

Looking forward to your positive response.

Best regards,
Haris Afzal""",
    "Fahad":
    "\n"
"""Dear Mr. Fahad,

I am reaching out with the sincere hope that you will accept my invitation to dinner. Your unparalleled genius in literature and drama has always fascinated me. It would be a remarkable experience to converse with you and gain insight into your incredible mind.

Yours sincerely,
Haris Afzal"""}

# Printing the initial invitations
print("Initial Invitations:")
for guest in guests:
    print(messages[guest])

# Information about a bigger dinner table
print("\nGreat news! We have found a bigger dinner table, so we can invite more guests.\n")

# Adding more guests
# Insert a new guest at the beginning
guests.insert(0, "Shani.")

# Insert a new guest in the middle
middle_index = len(guests) // 2
guests.insert(middle_index, "Abbas")

# Append a new guest at the end 
guests.append("Khawar")

# Add new messages for the new guests
messages["Shani."] = """
Dear Mr. Shani,

I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your leadership and dedication to civil rights have always inspired me. It would be an honor to discuss your experiences and vision for a better world.

Looking forward to your positive response.

Best regards,
Haris Afzal
"""

messages["Abbas"] = """
Dear Mr. Abbas,

I am delighted to invite you to join me for dinner. Your artistry and courage in the face of adversity have always fascinated me. I would love to hear more about your creative process and experiences.

With great admiration,
Haris Afzal
"""

messages["Khawar"] = """
Dear Mr. Khawar,

I am excited to invite you to dinner. Your innovations and vision in technology have profoundly impacted the world. It would be a privilege to discuss your journey and insights with you.

Sincerely,
Haris Afzal
"""

# Printing the updated invitations
print("Updated Invitations:")
for guest in guests:
    print(messages[guest])
# Out:
# Initial Invitations:
# Dear Mr. Basit,
#
# I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in electrical engineering and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.
#
# Looking forward to your positive response.
#
# Best regards,
# Haris Afzal
#
# Dear Mr. Hamza,
#
# I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in computer science and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.
#
# Looking forward to your positive response.
#
# Best regards,
# Haris Afzal
#
# Dear Mr. Fahad,
#
# ...

# %%
# Initial guest list after adding more guests 
guests = [
    "Basit",
    "Hamza",
    "Shani",
    "Abbas",
    "Khawar",
    "Fahad"
]

# Messages dictionary
messages = {
    "Basit": """
Dear Mr. Basit,

I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your leadership and dedication to civil rights have always inspired me. It would be an honor to discuss your experiences and vision for a better world.

Looking forward to your positive response.

Best regards,
Haris Afzal
""",
    "Hamza": """
Dear Mr. Hamza, 

I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in electrical engineering and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.

Looking forward to your positive response.

Best regards,
Haris Afzal
""",
    "Shani": """
Dear Mr. Shani,

I am delighted to invite you to join me for dinner. Your artistry and courage in the face of adversity have always fascinated me. I would love to hear more about your creative process and experiences.

With great admiration,
Haris Afzal
""",
    "Abbas": """
Dear Mr. Abbas,

I am writing to extend a heartfelt invitation for you to join me for an evening of dinner and conversation. Your pioneering work in computer science and your visionary ideas have always inspired me. It would be an honor to discuss your innovations and learn from your experiences.

Looking forward to your positive response.

Best regards,
Haris Afzal
""",
    "Khawar": """
Dear Mr. Khawar,

I am reaching out with the sincere hope that you will accept my invitation to dinner. Your unparalleled genius in literature and drama has always fascinated me. It would be a remarkable experience to converse with you and gain insight into your incredible mind.

Yours sincerely,
Haris Afzal
""",
    "Fahad": """
Dear Mr. Fahad,

I am excited to invite you to dinner. Your innovations and vision in technology have profoundly impacted the world. It would be a privilege to discuss your journey and insights with you.

Sincerely,
Haris Afzal
"""
}

# Message about limited space
print("Unfortunately, I can invite only two people to dinner.\n")

# Remove guests one by one using pop()
while len(guests) > 2:
    removed_guest = guests.pop()
    print(f"sorry {removed_guest}, I can't invite you to dinner.")

# Print a message to the remaining guests
for guest in guests:
    print(f"{guest}, you are still invited to dinner!")

# Remove the last two guests using del and ensure the list is empty
del guests[0]
del guests[0] 

# Verify the list is empty
print("\nFinal guest list:", guests)
# Out:
# Unfortunately, I can invite only two people to dinner.
#
# sorry Fahad, I can't invite you to dinner.
# sorry Khawar, I can't invite you to dinner.
# sorry Abbas, I can't invite you to dinner.
# sorry Shani, I can't invite you to dinner.
# Basit, you are still invited to dinner!
# Hamza, you are still invited to dinner!
#
# Final guest list: []

# %%
# Creating a list
list = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# Indexing:
print (list[0])
print (list[-8])
print (list[-1])
print (list[3])
print (list[1])

print()

# Slicing:
print (list[0:5])
print (list[-8:-1])
print (list[1:7])
print (list[-7:-4])
# Out:
# 10
# 20
# 90
# 40
# 20
#
# [10, 20, 30, 40, 50]
# [20, 30, 40, 50, 60, 70, 80]
# [20, 30, 40, 50, 60, 70]
# [30, 40, 50]

# %%
def calculate_grade(percentage):
    if percentage >=90:
        return 'A'
    elif percentage >=80:
        return 'B'
    elif percentage >=70:
        return 'C'
    elif percentage >=60:
        return 'D'
    else:
        return 'F'

subjects = ["Maths", "Science", "English", "History", "Geography",]
marks = []

for subject in subjects:
    mark = float(input(f"Enter the marks for {subject}: "))
    marks.append(mark)

total_marks = sum(marks)
percentage = total_marks / len(subjects)
grade = calculate_grade(percentage)

print("\nMark Sheet")
print("----------")
for i in range(len(subjects)):
    print(f"{subjects[i]}: {marks[i]}")

print(f"\nTotal Marks: {total_marks}")
print(f"percentage: {percentage:.2f}%")
print(f"Grade: {grade}")
# Out:
# Enter the marks for Maths:  10
# Enter the marks for Science:  20
# Enter the marks for English:  50
# Enter the marks for History:  88
# Enter the marks for Geography:  45
# Mark Sheet
# ----------
# Maths: 10.0
# Science: 20.0
# English: 50.0
# History: 88.0
# Geography: 45.0
#
# Total Marks: 213.0
# percentage: 42.60%
# Grade: F
